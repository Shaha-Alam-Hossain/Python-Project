# %% [markdown]
# <a href="https://colab.research.google.com/github/Shaha-Alam-Hossain/Python-Project/blob/main/compound_interest.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
p = int(input ())
r = int(input ())
t = int(input ())

c = int(p*(1+10/100)**t)

print(c)
# Out:
# 2000
# 10
# 2
# 2420
