# %% [markdown]
# <a href="https://colab.research.google.com/github/Shaha-Alam-Hossain/Python-Project/blob/main/Name%20Tag.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
a = ("Alamgir")
b = ("Md,")

print(a,b)
# Out:
# Alamgir Md,
