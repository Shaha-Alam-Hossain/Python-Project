# %% [markdown]
# <a href="https://colab.research.google.com/github/Shaha-Alam-Hossain/Python-Project/blob/main/Task1%20Welcome%20Banner.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
print("Welcome to CSE,SUB \nCSE-1102-Lab \nLoading....done")
# Out:
# Welcome to CSE,SUB
# CSE-1102-Lab
# Loading....done
