# %% [markdown]
# <a href="https://colab.research.google.com/github/Shaha-Alam-Hossain/Python-Project/blob/main/T3%20Swap%20Without%20a%20Third%20Variable.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
a = 10
b = 12
print("Value of a is:",a*b/10,"\n""Value of b is:",b*a/12)
# Out:
# Value of a is: 12.0
# Value of b is: 10.0
