# %% [markdown]
# <a href="https://colab.research.google.com/github/Shaha-Alam-Hossain/Python-Project/blob/main/Say%20Hello%20World.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
a = int(input())
b = int(input())
sum = a+b
print(sum)
# Out:
# 200
# 100
# 300
