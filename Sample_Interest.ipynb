# %% [markdown]
# <a href="https://colab.research.google.com/github/Shaha-Alam-Hossain/Python-Project/blob/main/Sample_Interest.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
p = int(input ())
r = int(input ())
t = int(input ())

i = p*10/100*t

print(i)
# Out:
# 1200
# 10
# 4
# 480.0
